# %%
import pandas as pd
import sqlalchemy

# %%
engine =sqlalchemy.create_engine("mysql+pymysql://lambdauser:Lambda007#@globalpulsemasterrds-us-west-2b.cc0ff0tjrrid.us-west-2.rds.amazonaws.com:3306/master")

# %%
df = pd.read_sql_table("scfJob",engine)
df
# Out:
#          jobId isMeta jobCreatedBy        jobStartDate          jobEndDate  \
# 0    1-XKV3F0T   True   PERFAUTO_4 2018-11-28 16:31:33 2018-11-28 16:31:38
# 1    1-XM93ZZN   True   PERFAUTO_4 2018-12-03 09:04:53 2018-12-03 09:05:00
# 2    1-XMI24EG   True   PERFAUTO_4 2018-12-03 19:52:14                 NaT
# 3    1-XMI24ER   True   PERFAUTO_4 2018-12-03 21:18:44                 NaT
# 4    1-XMTQQZX   True   PERFAUTO_4 2018-12-03 23:29:13 2018-12-03 23:29:16
# 5    1-XMVXO00   True   PERFAUTO_4 2018-12-03 23:04:46                 NaT
# 6    1-XN31XB4   True   PERFAUTO_4 2018-12-04 03:10:43 2018-12-04 03:10:48
# 7    1-XN31XBK   True   PERFAUTO_4 2018-12-04 04:21:59                 NaT
# 8    1-XN83XJO   True   PERFAUTO_4 2018-12-04 18:21:31 2018-12-04 18:21:38
# 9    1-XN83XK2   True   PERFAUTO_4 2018-12-04 18:36:30                 NaT
# 10   1-XN8QPR9   True   PERFAUTO_4 2018-12-05 06:12:41 2018-12-05 06:14:22
# ...

# %%
data = df.groupby("productLineCode")
data.get_group("ACD")
# Out:
#          jobId isMeta jobCreatedBy        jobStartDate          jobEndDate  \
# 2    1-XMI24EG   True   PERFAUTO_4 2018-12-03 19:52:14                 NaT
# 3    1-XMI24ER   True   PERFAUTO_4 2018-12-03 21:18:44                 NaT
# 5    1-XMVXO00   True   PERFAUTO_4 2018-12-03 23:04:46                 NaT
# 6    1-XN31XB4   True   PERFAUTO_4 2018-12-04 03:10:43 2018-12-04 03:10:48
# 7    1-XN31XBK   True   PERFAUTO_4 2018-12-04 04:21:59                 NaT
# 8    1-XN83XJO   True   PERFAUTO_4 2018-12-04 18:21:31 2018-12-04 18:21:38
# 9    1-XN83XK2   True   PERFAUTO_4 2018-12-04 18:36:30                 NaT
# 11   1-XN8QPRC   True   PERFAUTO_4 2018-12-05 06:33:15                 NaT
# 12   1-XN8QPRF   True   PERFAUTO_4 2018-12-05 06:37:38                 NaT
# 13   1-XN9233K   True   PERFAUTO_4 2018-12-05 12:50:54                 NaT
# 14   1-XNA7D7D   True   PERFAUTO_4 2018-12-06 01:23:02 2018-12-05 17:23:12
# ...

# %%
query = '''select * from scfJob group by productLabel'''
df = pd.read_sql_query(query,engine)
df
# Out:
#         jobId isMeta jobCreatedBy        jobStartDate           jobEndDate  \
# 0   1-XNOS9G5   True   PERFAUTO_6 2018-12-07 15:34:50  0000-00-00 00:00:00
# 1   1-XKV3F0T   True   PERFAUTO_4 2018-11-28 16:31:33  2018-11-28 16:31:38
# 2   1-XQ6BJRH  False   PERFAUTO_4 2018-12-17 23:12:19  0000-00-00 00:00:00
# 3   1-XQ645NK   True   PERFAUTO_4 2018-12-14 17:28:10  2018-12-14 17:28:16
# 4   1-XMI24EG   True   PERFAUTO_4 2018-12-03 19:52:14  0000-00-00 00:00:00
# 5   1-XM93ZZN   True   PERFAUTO_4 2018-12-03 09:04:53  2018-12-03 09:05:00
# 6   1-XRARGSB   True   PERFAUTO_4 2018-12-19 19:10:51  2018-12-19 19:11:05
# 7   1-XOI2T3N   True   PERFAUTO_4 2018-12-12 22:10:26  2018-12-12 22:14:45
# 8   1-XMTQQZX   True   PERFAUTO_4 2018-12-03 23:29:13  2018-12-03 23:29:16
# 9   1-XNEHGIF   True   PERFAUTO_4 2018-12-07 21:25:55  2018-12-07 21:29:09
# 10  1-XOJ4RGB   True   PERFAUTO_4 2018-12-11 18:42:46  0000-00-00 00:00:00
# ...
